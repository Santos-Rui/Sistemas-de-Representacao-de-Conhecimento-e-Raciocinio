# %%
import pandas

# %%
data = pandas.read_csv("teste.csv")

# %%
data
# Out:
#    gid   latitude  longitude Estado de Conservacao     Tipo de Abrigo  \
# 0  183 -103678.36  -96590.26                   Bom  Fechado dos Lados
# 1  791 -103705.46  -96673.60                   Bom   Aberto dos Lados
# 2  595 -103725.69  -95975.20                   Bom  Fechado dos Lados
# 3  182 -103746.76  -96396.66                   Bom  Fechado dos Lados
# 4  499 -103758.44  -94393.36                   Bom  Fechado dos Lados
# 5  593 -103777.02  -94637.67                   Bom         Sem Abrigo
#
#   Abrigo com Publicidade? Operadora  Carreira  Codigo de Rua  \
# 0                     Yes    Vimeca         1            286
# 1                     Yes    Vimeca         1            286
# 2                     Yes    Vimeca         1            354
# 3                     Yes  SCoTTURB         1            286
# 4                     Yes    Vimeca         1            300
# 5                      No    Vimeca         1            300
#
# ...

# %%
import os
import pandas


directory = r'C:/Users/Ruca-WindowsX/Desktop/Dados/CSV'
file = open("MyFile.txt","a") 

for filename in os.listdir(directory):
    indexx = 1
    file.write("%"+str(filename) )
    file.write("\n")
    file.write("\n")
    
    
    data = pandas.read_csv('C:/Users/Ruca-WindowsX/Desktop/Dados/CSV/' +filename).dropna()
    

    print (str (filename))

    for index, row in data.iterrows():
    
    

       file.write("paragem( " )
          
       
      
       
       file.write(str(indexx))
       file.write(" , ")
       
       file.write(str(row['Carreira']))
       file.write(" , ")
        

       file.write(str(row['gid']))
       file.write(" , ")
       

       file.write(str(row['latitude']))
       file.write(" , ")
       
       file.write(str(row['longitude']))
       file.write(" , ")
       
       file.write("'")
       file.write(row['Estado de Conservacao'])
       file.write("'")
       file.write(" , ")
       
       file.write("'")
       file.write(row['Tipo de Abrigo'])
       file.write("'")
       file.write(" , ")
       
       file.write("'")
       file.write(row['Abrigo com Publicidade?'])
       file.write("'")
       file.write(" , ")
       
       file.write("'")
       file.write(row['Operadora'])
       file.write("'")
       file.write(" , ")
       
       
       file.write(str(row['Codigo de Rua']))
       file.write(" , ")
       
       file.write("'")
       file.write(str(row['Nome da Rua']))
       file.write("'")
       file.write(" , ")
       
       file.write("'")
       file.write(row['Freguesia'])
       file.write("'")
       
       
       file.write(").")
       file.write("\n")
       indexx+=1
    file.write("\n")
    file.write("\n")
    file.write("\n")
    file.write("\n")
    file.write("\n")
    file.write("\n")

file.close()
# Out:
# lista_adjacencias_paragens_01.csv
# lista_adjacencias_paragens_02.csv
# lista_adjacencias_paragens_06.csv
# lista_adjacencias_paragens_07.csv
# lista_adjacencias_paragens_10.csv
# lista_adjacencias_paragens_101.csv
# lista_adjacencias_paragens_102.csv
# lista_adjacencias_paragens_106.csv
# lista_adjacencias_paragens_108.csv
# lista_adjacencias_paragens_11.csv
# lista_adjacencias_paragens_111.csv
# lista_adjacencias_paragens_112.csv
# lista_adjacencias_paragens_114.csv
# lista_adjacencias_paragens_115.csv
# lista_adjacencias_paragens_116.csv
# lista_adjacencias_paragens_117.csv
# lista_adjacencias_paragens_119.csv
# lista_adjacencias_paragens_12.csv
# lista_adjacencias_paragens_122.csv
# lista_adjacencias_paragens_125.csv
# lista_adjacencias_paragens_129.csv
# lista_adjacencias_paragens_13.csv
# lista_adjacencias_paragens_15.csv
# lista_adjacencias_paragens_158.csv
# lista_adjacencias_paragens_162.csv
# lista_adjacencias_paragens_171.csv
# lista_adjacencias_paragens_184.csv
# ...

# %%
file = open("MyFile.txt","a") 

file.close()
